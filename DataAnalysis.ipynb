# %%
import pandas as pd
from scipy.stats import chi2_contingency
# Create the contingency table
data = [[20, 30],  # Male: [Like, Dislike]
        [25, 25]]  # Female: [Like, Dislike]
# Create a DataFrame for clarity
df = pd.DataFrame(data, columns=["Like", "Dislike"], index=["Male", "Female"])
# Perform the Chi-Square Test
chi2, p, dof, expected = chi2_contingency(df)
# Display results
print("Chi-square Statistic:", chi2)
print("Degrees of Freedom:", dof)
print("P-value:", p)
print("Expected Frequencies:\n", expected)
# Out:
# Chi-square Statistic: 0.6464646464646464
# Degrees of Freedom: 1
# P-value: 0.4213795037428696
# Expected Frequencies:
#  [[22.5 27.5]
#  [22.5 27.5]]

# %%
import gspread
import pandas as pd
from gspread_dataframe import get_as_dataframe, set_with_dataframe
MEO_CRED = {
  "type": "service_account",
  "project_id": "flowing-access-432509-u5",
  "private_key_id": "af59234402471d06c30289f1841f9877a2213cf2",
  "private_key": "-----BEGIN PRIVATE KEY-----\\nKPEbubWIBLd5teGVYr4Da0e7\n-----END PRIVATE KEY-----\n",
  "client_email": "meomata@flowing-access-432509-u5.iam.gserviceaccount.com",
  "client_id": "117428780670557965479",
  "auth_uri": "https://accounts.google.com/o/oauth2/auth",
  "token_uri": "https://oauth2.googleapis.com/token",
  "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
  "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/meomata%40flowing-access-432509-u5.iam.gserviceaccount.com",
  "universe_domain": "googleapis.com"
}
SHEET_ID = "1wYaYMSCGXxkNxBb1zxcp2cFi1z0Xf0aXPB7e16Er7a8"
gc = gspread.service_account_from_dict(MEO_CRED)
sh = gc.open_by_key(SHEET_ID)
def read_sheet(sheet_name):
    worksheet = sh.worksheet(sheet_name)
    return get_as_dataframe(worksheet, evaluate_formulas=True, dtype=str).dropna(how="all")
gsEPI = read_sheet("EPI")

# %%
gsEPI
# Out:
#              Date Team  Tsp WardVillage         WardCode Approach Visit_no  \
# 0      2-Jan-2025    5  SDG         107  MMR013018701527      PPM        1
# 1      2-Jan-2025    5  SDG         107  MMR013018701527      PPM        1
# 2      2-Jan-2025    5  SDG         107  MMR013018701527      PPM        1
# 3      2-Jan-2025    5  SDG         107  MMR013018701527      PPM        1
# 4      5-Jan-2025    5  SDG         107  MMR013018701527      PPM        1
# ...           ...  ...  ...         ...              ...      ...      ...
# 32005  1-Nov-2024    5  SDG         NaN              NaN      PPM      NaN
# 32006  1-Dec-2024    5  SDG         NaN              NaN      PPM      NaN
# 32007  1-Oct-2024    5  SDG         NaN              NaN      PPM      NaN
# 32008  1-Nov-2024    5  SDG         NaN              NaN      PPM      NaN
# 32009  1-Dec-2024    5  SDG         NaN              NaN      PPM      NaN
#
# ...

# %%
print(gsEPI.columns.to_list())
# Out:
# ['Date', 'Team', 'Tsp', 'WardVillage', 'WardCode', 'Approach', 'Visit_no', 'Sr_No', 'PatientID', 'Name', 'Age', 'Sex', 'Address', 'Ptstsp', 'PhoneNo', 'Origin', 'VOL', 'Referralfor', 'VolunteerName', 'Organization', 'Cough', 'Fever', 'Wtloss', 'Nightsweat', 'Haemoptysis', 'Chestpain', 'Fatigue', 'Neckglands', 'TBcontact', 'MDRTBcontact', 'TBTreatmenthistory', 'Covid19history', 'DiabetesDM', 'Smoking', 'Reasonforexamination', 'TypeofPatient', 'PublicHealthCare1', 'TypeofPatient1', 'DM1', 'HT1', 'DMHT1', 'RTIAVI1', 'Generalweakness1', 'Other1', 'Cxrr', 'CXRresult', 'Cxr_others', 'Sputum_request', 'Micror', 'Sputummicroscopyresult', 'Genexpertrequested', 'GeneXpertresult', 'CultureDSTresult', 'Bact_status', 'Case', 'Treatmentreferral', 'TreatmentRegimen', 'Placeforreferral', 'Ref1', 'TreatmentOutcome', 'Seeing', 'Hearing', 'Walking', 'Cognition', 'Selfcare', 'Communication', 'Disability', 'Remark', 'Month (Diagnosis)', 'Location1', 'SDG_EPI', 'TB1', 'CXRresultFinal', 'Xray2ndReading1', 
# ...

# %%
df_gs = gsEPI[['Sex','Age']].copy()
df_gs['Sex'] = df_gs['Sex'].astype(int)
df_gs['Age'] = df_gs['Age'].astype(float)
df_gs.dropna(axis=0,inplace=True)

# %%
df_gs
# Out:
#        Sex   Age
# 0        1   2.0
# 1        2  59.0
# 2        1  47.0
# 3        2   6.0
# 4        2  32.0
# ...    ...   ...
# 31709    1   9.0
# 31710    1  57.0
# 31711    1  78.0
# 31712    2  58.0
# 31713    2  68.0
#
# [31714 rows x 2 columns]

# %%
gchi2,gp,gdof,gexpected = chi2_contingency(df_gs)
print("CHI: ",gchi2)
print("P: ",gp)
print("DOF: ",gdof)
print("EXPECTED: ",gexpected)

# %%
chsex = df_gs.copy()
chsex['Sex'] = chsex['Sex'].replace({1:"Male",2:"Female"})
chsex['Age'].max()
# Out:
# 99.0

# %%
import numpy as np
# Out:
# <BarContainer object of 31714 artists>
